# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in ./opt/anaconda3/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: joblib in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (4.64.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/josiahjames/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
import nltk
import matplotlib as plt
import pandas as pd
import math
from nltk.corpus import brown
import numpy as np
nltk.download('brown')
from nltk.corpus import brown
brown.categories()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
print("Length of words is: ")
len(brown.words()) #tokens
# Out:
# Length of words is:
# 1161192

# %%
number_of_words = 0
with open('nlp.txt','r') as file:
	data = file.read()
	lines = data.split()
	number_of_words += len(lines)
print("Total number of words:")
print(number_of_words)
# Out:
# Total number of words:
# 200

# %%
f = open("NLP.txt", 'r', errors = 'ignore')
x = f.read()
x
# Out:
# 'Starting from the 1990s, postmodern criminology has been gaining substantial importance. This discipline lays particular emphasis on such aspects as gender, class, and race in its theories of the origins of crime. According to Arrigo (2019), postmodern criminology recognizes the specific value of language as a non-neutral, politically charged instrument of communication. Linguistic elements serve to represent the views and the values of a particular social group.\nSuch a notion as the violence of language suggests that words may carry damaging meaning, being an oppression tool in the modern environment. Arrigo (2019) states that the courtroom discourse is often offensive to some participants of the process, representing the phenomenon of linguistic oppression, referring to the Los Angeles riots resulting from such a situation. Postmodern criminology aims at investigating such negative tendencies and providing potential solutions. Women appear to be one of the groups, which have been experiencing the system’s oppression in current settings. Arrigo (2019) writes that most criminology education activities are conducted by white males representing the middle class. Accordingly, women who pursue criminology have their professors’ and supervisors’ views imposed on them. This hegemony is expressed through particular linguistic patterns, which reveal their discriminatory nature after thorough analysis.'

# %%
from collections import Counter
the_count = Counter(x)
print(the_count)
# Out:
# Counter({' ': 198, 'e': 127, 'i': 109, 's': 98, 'o': 97, 'n': 95, 't': 94, 'r': 85, 'a': 73, 'c': 50, 'g': 46, 'h': 44, 'p': 37, 'm': 36, 'l': 36, 'u': 35, 'd': 26, 'f': 18, 'v': 16, 'y': 15, ',': 11, '.': 11, 'w': 9, 'b': 6, 'A': 6, '9': 5, '1': 4, '0': 4, '(': 3, '2': 3, ')': 3, '’': 3, 'S': 2, 'T': 2, 'L': 2, 'x': 2, 'z': 1, '-': 1, '\n': 1, 'P': 1, 'W': 1})

# %%
import nltk
import matplotlib as plt
import pandas as pd
import math
from nltk.corpus import brown
import numpy as np
nltk.download('brown')
from nltk.corpus import brown
brown.categories()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories='government')
# Out:
# ['The', 'Office', 'of', 'Business', 'Economics', '(', ...]

# %%
from collections import Counter
split_it = x.split()
Counter = Counter(split_it)
most_occur = Counter.most_common(4)
print(most_occur)
# Out:
# [('the', 14), ('of', 9), ('criminology', 5), ('to', 5)]

# %%
nltk.download('punkt') 
nltk.download('wordnet') 
from nltk.tokenize import sent_tokenize, word_tokenize
sentences= nltk.sent_tokenize(x)
length= len(sentences)
length
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 11

# %%
nltk.download('treebank')
from nltk.corpus import treebank
print(treebank.fileids())
print(treebank.words('wsj_0003.mrg'))
print(treebank.tagged_words('wsj_0003.mrg'))
print(treebank.parsed_sents('wsj_0003.mrg')[0])
# Out:
# ['wsj_0001.mrg', 'wsj_0002.mrg', 'wsj_0003.mrg', 'wsj_0004.mrg', 'wsj_0005.mrg', 'wsj_0006.mrg', 'wsj_0007.mrg', 'wsj_0008.mrg', 'wsj_0009.mrg', 'wsj_0010.mrg', 'wsj_0011.mrg', 'wsj_0012.mrg', 'wsj_0013.mrg', 'wsj_0014.mrg', 'wsj_0015.mrg', 'wsj_0016.mrg', 'wsj_0017.mrg', 'wsj_0018.mrg', 'wsj_0019.mrg', 'wsj_0020.mrg', 'wsj_0021.mrg', 'wsj_0022.mrg', 'wsj_0023.mrg', 'wsj_0024.mrg', 'wsj_0025.mrg', 'wsj_0026.mrg', 'wsj_0027.mrg', 'wsj_0028.mrg', 'wsj_0029.mrg', 'wsj_0030.mrg', 'wsj_0031.mrg', 'wsj_0032.mrg', 'wsj_0033.mrg', 'wsj_0034.mrg', 'wsj_0035.mrg', 'wsj_0036.mrg', 'wsj_0037.mrg', 'wsj_0038.mrg', 'wsj_0039.mrg', 'wsj_0040.mrg', 'wsj_0041.mrg', 'wsj_0042.mrg', 'wsj_0043.mrg', 'wsj_0044.mrg', 'wsj_0045.mrg', 'wsj_0046.mrg', 'wsj_0047.mrg', 'wsj_0048.mrg', 'wsj_0049.mrg', 'wsj_0050.mrg', 'wsj_0051.mrg', 'wsj_0052.mrg', 'wsj_0053.mrg', 'wsj_0054.mrg', 'wsj_0055.mrg', 'wsj_0056.mrg', 'wsj_0057.mrg', 'wsj_0058.mrg', 'wsj_0059.mrg', 'wsj_0060.mrg', 'wsj_0061.mrg', 'wsj_0062.mrg', 'wsj_0063.mrg', 'wsj_0064.mrg', 'wsj_0065.mrg', 'wsj_0066.mrg', 'wsj_0067.mrg', 'wsj_0068.mrg', 'wsj_0069.mrg', 'wsj_0070.mrg', 'wsj_0071.mrg', 'wsj_0072.mrg', 'wsj_0073.mrg', 'wsj_0074.mrg', 'wsj_0075.mrg', 'wsj_0076.mrg', 'wsj_0077.mrg', 'wsj_0078.mrg', 'wsj_0079.mrg', 'wsj_0080.mrg', 'wsj_0081.mrg', 'wsj_0082.mrg', 'wsj_0083.mrg', 'wsj_0084.mrg', 'wsj_0085.mrg', 'wsj_0086.mrg', 'wsj_0087.mrg', 'wsj_0088.mrg', 'wsj_0089.mrg', 'wsj_0090.mrg', 'wsj_0091.mrg', 'wsj_0092.mrg', 'wsj_0093.mrg', 'wsj_0094.mrg', 'wsj_0095.mrg', 'wsj_0096.mrg', 'wsj_0097.mrg', 'wsj_0098.mrg', 'wsj_0099.mrg', 'wsj_0100.mrg', 'wsj_0101.mrg', 'wsj_0102.mrg', 'wsj_0103.mrg', 'wsj_0104.mrg', 'wsj_0105.mrg', 'wsj_0106.mrg', 'wsj_0107.mrg', 'wsj_0108.mrg', 'wsj_0109.mrg', 'wsj_0110.mrg', 'wsj_0111.mrg', 'wsj_0112.mrg', 'wsj_0113.mrg', 'wsj_0114.mrg', 'wsj_0115.mrg', 'wsj_0116.mrg', 'wsj_0117.mrg', 'wsj_0118.mrg', 'wsj_0119.mrg', 'wsj_0120.mrg', 'wsj_0121.mrg', 'wsj_0122.mrg', 'wsj_0123.mrg', 'wsj_0124.mrg', 'wsj_0125.mrg', 'wsj_0126.mrg', 'wsj_0127.mrg', 'wsj_0128.mrg', 'wsj_0129.mrg', 'wsj_0130.mrg', 'wsj_0131.mrg', 'wsj_0132.mrg', 'wsj_0133.mrg', 'wsj_0134.mrg', 'wsj_0135.mrg', 'wsj_0136.mrg', 'wsj_0137.mrg', 'wsj_0138.mrg', 'wsj_0139.mrg', 'wsj_0140.mrg', 'wsj_0141.mrg', 'wsj_0142.mrg', 'wsj_0143.mrg', 'wsj_0144.mrg', 'wsj_0145.mrg', 'wsj_0146.mrg', 'wsj_0147.mrg', 'wsj_0148.mrg', 'wsj_0149.mrg', 'wsj_0150.mrg', 'wsj_0151.mrg', 'wsj_0152.mrg', 'wsj_0153.mrg', 'wsj_0154.mrg', 'wsj_0155.mrg', 'wsj_0156.mrg', 'wsj_0157.mrg', 'wsj_0158.mrg', 'wsj_0159.mrg', 'wsj_0160.mrg', 'wsj_0161.mrg', 'wsj_0162.mrg', 'wsj_0163.mrg', 'wsj_0164.mrg', 'wsj_0165.mrg', 'wsj_0166.mrg', 'wsj_0167.mrg', 'wsj_0168.mrg', 'wsj_0169.mrg', 'wsj_0170.mrg', 'wsj_0171.mrg', 'wsj_0172.mrg', 'wsj_0173.mrg', 'wsj_0174.mrg', 'wsj_0175.mrg', 'wsj_0176.mrg', 'wsj_0177.mrg', 'wsj_0178.mrg', 'wsj_0179.mrg', 'wsj_0180.mrg', 'wsj_0181.mrg', 'wsj_0182.mrg', 'wsj_0183.mrg', 'wsj_0184.mrg', 'wsj_0185.mrg', 'wsj_0186.mrg', 'wsj_0187.mrg', 'wsj_0188.mrg', 'wsj_0189.mrg', 'wsj_0190.mrg', 'wsj_0191.mrg', 'wsj_0192.mrg', 'wsj_0193.mrg', 'wsj_0194.mrg', 'wsj_0195.mrg', 'wsj_0196.mrg', 'wsj_0197.mrg', 'wsj_0198.mrg', 'wsj_0199.mrg']
# ['A', 'form', 'of', 'asbestos', 'once', 'used', '*', ...]
# [('A', 'DT'), ('form', 'NN'), ('of', 'IN'), ...]
# (S
#   (S-TPC-1
#     (NP-SBJ
#       (NP (NP (DT A) (NN form)) (PP (IN of) (NP (NN asbestos))))
#       (RRC
#         (ADVP-TMP (RB once))
#         (VP
#           (VBN used)
#           (NP (-NONE- *))
#           (S-CLR
#             (NP-SBJ (-NONE- *))
#             (VP
#               (TO to)
#               (VP
#                 (VB make)
#                 (NP (NNP Kent) (NN cigarette) (NNS filters))))))))
#     (VP
#       (VBZ has)
#       (VP
#         (VBN caused)
#         (NP
#           (NP (DT a) (JJ high) (NN percentage))
#           (PP (IN of) (NP (NN cancer) (NNS deaths)))
#           (PP-LOC
#             (IN among)
#             (NP
#               (NP (DT a) (NN group))
#               (PP
#                 (IN of)
#                 (NP
#                   (NP (NNS workers))
#                   (RRC
#                     (VP
#                       (VBN exposed)
#                       (NP (-NONE- *))
#                       (PP-CLR (TO to) (NP (PRP it)))
#                       (ADVP-TMP
#                         (NP
#                           (QP (RBR more) (IN than) (CD 30))
#                           (NNS years))
#                         (IN ago))))))))))))
#   (, ,)
#   (NP-SBJ (NNS researchers))
#   (VP (VBD reported) (SBAR (-NONE- 0) (S (-NONE- *T*-1))))
#   (. .))
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
from nltk.corpus import brown
print(brown.words())
print(brown.tagged_words())
print(brown.sents())
print(brown.tagged_sents())
print(brown.paras(categories='reviews'))
print(brown.tagged_paras(categories='reviews'))
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]
# [[('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')], [('The', 'AT'), ('jury', 'NN'), ('further', 'RBR'), ('said', 'VBD'), ('in', 'IN'), ('term-end', 'NN'), ('presentments', 'NNS'), ('that', 'CS'), ('the', 'AT'), ('City', 'NN-TL'), ('Executive', 'JJ-TL'), ('Committee', 'NN-TL'), (',', ','), ('which', 'WDT'), ('had', 'HVD'), ('over-all', 'JJ'), ('charge', 'NN'), ('of', 'IN'), ('the', 'AT'), ('election', 'NN'), (',', ','), ('``', '``'), ('deserves', 'VBZ'), ('the', 'AT'), ('praise', 'NN'), ('and', 'CC'), ('thanks', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('City', 'NN-TL'), ('of', 'IN-TL'), ('Atlanta', 'NP-TL'), ("''", "''"), ('for', 'IN'), ('the', 'AT'), ('manner', 'NN'), ('in', 'IN'), ('which', 'WDT'), ('the', 'AT'), ('election', 'NN'), ('was', 'BEDZ'), ('conducted', 'VBN'), ('.', '.')], ...]
# [[['It', 'is', 'not', 'news', 'that', 'Nathan', 'Milstein', 'is', 'a', 'wizard', 'of', 'the', 'violin', '.'], ['Certainly', 'not', 'in', 'Orchestra', 'Hall', 'where', 'he', 'has', 'played', 'countless', 'recitals', ',', 'and', 'where', 'Thursday', 'night', 'he', 'celebrated', 'his', '20th', 'season', 'with', 'the', 'Chicago', 'Symphony', 'Orchestra', ',', 'playing', 'the', 'Brahms', 'Concerto', 'with', 'his', 'own', 'slashing', ',', 'demon-ridden', 'cadenza', 'melting', 'into', 'the', 'high', ',', 'pale', ',', 'pure', 'and', 'lovely', 'song', 'with', 'which', 'a', 'violinist', 'unlocks', 'the', 'heart', 'of', 'the', 'music', ',', 'or', 'forever', 'finds', 'it', 'closed', '.']], [['There', 'was', 'about', 'that', 'song', 'something', 'incandescent', ',', 'for', 'this', 'Brahms', 'was', 'Milstein', 'at', 'white', 'heat', '.'], ['Not', 'the', 'noblest', 'performance', 'we', 'have', 'heard', 'him', 'play', ',', 'or', 'the', 'most', 'spacious', ',', 'or', 'even', 'the', 'most', 'eloquent', '.'], ['Those', 'would', 'be', 'reserved', 'for', 'the', "orchestra's", 'great', 'nights', 'when', 'the', 'soloist', 'can', 'surpass', 'himself', '.'], ['This', 'time', 'the', 'orchestra', 'gave', 'him', 'some', 'superb', 'support', 'fired', 'by', 'response', 'to', 'his', 'own', 'high', 'mood', '.'], ['But', 'he', 'had', 'in', 'Walter', 'Hendl', 'a', 'willing', 'conductor', 'able', 'only', 'up', 'to', 'a', 'point', '.']], ...]
# [[[('It', 'PPS'), ('is', 'BEZ'), ('not', '*'), ('news', 'NN'), ('that', 'CS'), ('Nathan', 'NP'), ('Milstein', 'NP'), ('is', 'BEZ'), ('a', 'AT'), ('wizard', 'NN'), ('of', 'IN'), ('the', 'AT'), ('violin', 'NN'), ('.', '.')], [('Certainly', 'RB'), ('not', '*'), ('in', 'IN'), ('Orchestra', 'NN-TL'), ('Hall', 'NN-TL'), ('where', 'WRB'), ('he', 'PPS'), ('has', 'HVZ'), ('played', 'VBN'), ('countless', 'JJ'), ('recitals', 'NNS'), (',', ','), ('and', 'CC'), ('where', 'WRB'), ('Thursday', 'NR'), ('night', 'NN'), ('he', 'PPS'), ('celebrated', 'VBD'), ('his', 'PP$'), ('20th', 'OD'), ('season', 'NN'), ('with', 'IN'), ('the', 'AT'), ('Chicago', 'NP-TL'), ('Symphony', 'NN-TL'), ('Orchestra', 'NN-TL'), (',', ','), ('playing', 'VBG'), ('the', 'AT'), ('Brahms', 'NP-TL'), ('Concerto', 'NN-TL'), ('with', 'IN'), ('his', 'PP$'), ('own', 'JJ'), ('slashing', 'VBG'), (',', ','), ('demon-ridden', 'JJ'), ('cadenza', 'NN'), ('melting', 'VBG'), ('into', 'IN'), ('the', 'AT'), ('high', 'JJ'), (',', ','), ('pale', 'JJ'), (',', ','), ('pure', 'JJ'), ('and', 'CC'), ('lovely', 'JJ'), ('song', 'NN'), ('with', 'IN'), ('which', 'WDT'), ('a', 'AT'), ('violinist', 'NN'), ('unlocks', 'VBZ'), ('the', 'AT'), ('heart', 'NN'), ('of', 'IN'), ('the', 'AT'), ('music', 'NN'), (',', ','), ('or', 'CC'), ('forever', 'RB'), ('finds', 'VBZ'), ('it', 'PPO'), ('closed', 'VBN'), ('.', '.')]], [[('There', 'EX'), ('was', 'BEDZ'), ('about', 'IN'), ('that', 'DT'), ('song', 'NN'), ('something', 'PN'), ('incandescent', 'JJ'), (',', ','), ('for', 'CS'), ('this', 'DT'), ('Brahms', 'NP'), ('was', 'BEDZ'), ('Milstein', 'NP'), ('at', 'IN'), ('white', 'JJ'), ('heat', 'NN'), ('.', '.')], [('Not', '*'), ('the', 'AT'), ('noblest', 'JJT'), ('performance', 'NN'), ('we', 'PPSS'), ('have', 'HV'), ('heard', 'VBN'), ('him', 'PPO'), ('play', 'VB'), (',', ','), ('or', 'CC'), ('the', 'AT'), ('most', 'QL'), ('spacious', 'JJ'), (',', ','), ('or', 'CC'), ('even', 'RB'), ('the', 'AT'), ('most', 'QL'), ('eloquent', 'JJ'), ('.', '.')], [('Those', 'DTS'), ('would', 'MD'), ('be', 'BE'), ('reserved', 'VBN'), ('for', 'IN'), ('the', 'AT'), ("orchestra's", 'NN$'), ('great', 'JJ'), ('nights', 'NNS'), ('when', 'WRB'), ('the', 'AT'), ('soloist', 'NN'), ('can', 'MD'), ('surpass', 'VB'), ('himself', 'PPL'), ('.', '.')], [('This', 'DT'), ('time', 'NN'), ('the', 'AT'), ('orchestra', 'NN'), ('gave', 'VBD'), ('him', 'PPO'), ('some', 'DTI'), ('superb', 'JJ'), ('support', 'NN'), ('fired', 'VBN'), ('by', 'IN'), ('response', 'NN'), ('to', 'IN'), ('his', 'PP$'), ('own', 'JJ'), ('high', 'JJ'), ('mood', 'NN'), ('.', '.')], [('But', 'CC'), ('he', 'PPS'), ('had', 'HVD'), ('in', 'IN'), ('Walter', 'NP'), ('Hendl', 'NP'), ('a', 'AT'), ('willing', 'JJ'), ('conductor', 'NN'), ('able', 'JJ'), ('only', 'RB'), ('up', 'IN'), ('to', 'IN'), ('a', 'AT'), ('point', 'NN'), ('.', '.')]], ...]

# %%
nltk.download('indian')
from nltk.corpus import indian
print(indian.words()) 
print(indian.tagged_words())
# Out:
# ['মহিষের', 'সন্তান', ':', 'তোড়া', 'উপজাতি', '৷', ...]
# [('মহিষের', 'NN'), ('সন্তান', 'NN'), (':', 'SYM'), ...]
# [nltk_data] Downloading package indian to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package indian is already up-to-date!

# %%
nltk.download('universal_tagset')
nltk.download('conll2000')
nltk.download('switchboard')
print(brown.tagged_sents(tagset='universal'))
from nltk.corpus import conll2000, switchboard
print(conll2000.tagged_words(tagset='universal'))
# Out:
# [[('The', 'DET'), ('Fulton', 'NOUN'), ('County', 'NOUN'), ('Grand', 'ADJ'), ('Jury', 'NOUN'), ('said', 'VERB'), ('Friday', 'NOUN'), ('an', 'DET'), ('investigation', 'NOUN'), ('of', 'ADP'), ("Atlanta's", 'NOUN'), ('recent', 'ADJ'), ('primary', 'NOUN'), ('election', 'NOUN'), ('produced', 'VERB'), ('``', '.'), ('no', 'DET'), ('evidence', 'NOUN'), ("''", '.'), ('that', 'ADP'), ('any', 'DET'), ('irregularities', 'NOUN'), ('took', 'VERB'), ('place', 'NOUN'), ('.', '.')], [('The', 'DET'), ('jury', 'NOUN'), ('further', 'ADV'), ('said', 'VERB'), ('in', 'ADP'), ('term-end', 'NOUN'), ('presentments', 'NOUN'), ('that', 'ADP'), ('the', 'DET'), ('City', 'NOUN'), ('Executive', 'ADJ'), ('Committee', 'NOUN'), (',', '.'), ('which', 'DET'), ('had', 'VERB'), ('over-all', 'ADJ'), ('charge', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('election', 'NOUN'), (',', '.'), ('``', '.'), ('deserves', 'VERB'), ('the', 'DET'), ('praise', 'NOUN'), ('and', 'CONJ'), ('thanks', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('City', 'NOUN'), ('of', 'ADP'), ('Atlanta', 'NOUN'), ("''", '.'), ('for', 'ADP'), ('the', 'DET'), ('manner', 'NOUN'), ('in', 'ADP'), ('which', 'DET'), ('the', 'DET'), ('election', 'NOUN'), ('was', 'VERB'), ('conducted', 'VERB'), ('.', '.')], ...]
# [('Confidence', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ...]
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package switchboard to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package switchboard is already up-to-date!

# %%
#3
x = x.lower()
     

nltk.download('punkt') 
nltk.download('wordnet') 
from nltk.tokenize import sent_tokenize, word_tokenize
sent_tokens = nltk.sent_tokenize(x) 
word_tokens = nltk.word_tokenize(x) 
sent_tokens
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['starting from the 1990s, postmodern criminology has been gaining substantial importance.',
#  'this discipline lays particular emphasis on such aspects as gender, class, and race in its theories of the origins of crime.',
#  'according to arrigo (2019), postmodern criminology recognizes the specific value of language as a non-neutral, politically charged instrument of communication.',
#  'linguistic elements serve to represent the views and the values of a particular social group.',
#  'such a notion as the violence of language suggests that words may carry damaging meaning, being an oppression tool in the modern environment.',
#  'arrigo (2019) states that the courtroom discourse is often offensive to some participants of the process, representing the phenomenon of linguistic oppression, referring to the los angeles riots resulting from such a situation.',
#  'postmodern criminology aims at investigating such negative tendencies and providing potential solutions.',
#  'women appear to be one of the groups, which have been experiencing the system’s oppression in current settings.',
#  'arrigo (2019) writes that most criminology education activities are conducted by white males representing the middle class.',
#  'accordingly, women who pursue criminology have their professors’ and supervisors’ views imposed on them.',
#  'this hegemony is expressed through particular linguistic patterns, which reveal their discriminatory nature after thorough analysis.']

# %%
word_tokens
# Out:
# ['starting',
#  'from',
#  'the',
#  '1990s',
#  ',',
#  'postmodern',
#  'criminology',
#  'has',
#  'been',
#  'gaining',
#  'substantial',
#  'importance',
#  '.',
#  'this',
#  'discipline',
#  'lays',
#  'particular',
#  'emphasis',
#  'on',
#  'such',
#  'aspects',
#  'as',
#  'gender',
#  ',',
#  'class',
#  ',',
#  'and',
#  'race',
#  'in',
#  'its',
#  'theories',
#  'of',
#  'the',
#  'origins',
#  'of',
#  'crime',
#  '.',
#  'according',
#  'to',
#  'arrigo',
#  '(',
#  '2019',
#  ')',
#  ',',
#  'postmodern',
#  'criminology',
#  'recognizes',
#  'the',
#  'specific',
#  'value',
#  'of',
#  'language',
#  'as',
#  'a',
#  'non-neutral',
#  ',',
#  'politically',
#  'charged',
#  'instrument',
#  'of',
#  'communication',
#  '.',
#  'linguistic',
#  'elements',
#  'serve',
#  'to',
#  'represent',
#  'the',
#  'views',
#  'and',
#  'the',
#  'values',
#  'of',
#  'a',
#  'particular',
#  'social',
#  'group',
#  '.',
#  'such',
#  'a',
#  'notion',
#  'as',
#  'the',
#  'violence',
#  'of',
#  'language',
#  'suggests',
#  'that',
#  'words',
#  'may',
#  'carry',
#  'damaging',
#  'meaning',
#  ',',
#  'being',
#  'an',
#  'oppression',
#  'tool',
#  'in',
#  'the',
#  'modern',
#  'environment',
#  '.',
#  'arrigo',
#  '(',
#  '2019',
#  ')',
#  'states',
#  'that',
#  'the',
#  'courtroom',
#  'discourse',
#  'is',
#  'often',
#  'offensive',
#  'to',
#  'some',
#  'participants',
#  'of',
#  'the',
#  'process',
#  ',',
#  'representing',
#  'the',
#  'phenomenon',
#  'of',
#  'linguistic',
#  'oppression',
#  ',',
#  'referring',
#  'to',
#  'the',
#  'los',
#  'angeles',
#  'riots',
#  'resulting',
#  'from',
#  'such',
#  'a',
#  'situation',
#  '.',
#  'postmodern',
#  'criminology',
#  'aims',
#  'at',
#  'investigating',
#  'such',
#  'negative',
#  'tendencies',
#  'and',
#  'providing',
#  'potential',
#  'solutions',
#  '.',
#  'women',
#  'appear',
#  'to',
#  'be',
#  'one',
#  'of',
#  'the',
#  'groups',
#  ',',
#  'which',
#  'have',
#  'been',
#  'experiencing',
#  'the',
#  'system',
#  '’',
#  's',
#  'oppression',
#  'in',
#  'current',
#  'settings',
#  '.',
#  'arrigo',
#  '(',
#  '2019',
#  ')',
#  'writes',
#  'that',
#  'most',
#  'criminology',
#  'education',
#  'activities',
#  'are',
#  'conducted',
#  'by',
#  'white',
#  'males',
#  'representing',
#  'the',
#  'middle',
#  'class',
#  '.',
#  'accordingly',
#  ',',
#  'women',
#  'who',
#  'pursue',
#  'criminology',
#  'have',
#  'their',
#  'professors',
#  '’',
#  'and',
#  'supervisors',
#  '’',
#  'views',
#  'imposed',
#  'on',
#  'them',
#  '.',
#  'this',
#  'hegemony',
#  'is',
#  'expressed',
#  'through',
#  'particular',
#  'linguistic',
#  'patterns',
#  ',',
#  'which',
#  'reveal',
#  'their',
#  'discriminatory',
#  'nature',
#  'after',
#  'thorough',
#  'analysis',
#  '.']

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
tokens = word_tokenize(x)
filtered_text = [t for t in tokens if not t in stopwords.words("english")]
print(" ".join(filtered_text))
# Out:
# starting 1990s , postmodern criminology gaining substantial importance . discipline lays particular emphasis aspects gender , class , race theories origins crime . according arrigo ( 2019 ) , postmodern criminology recognizes specific value language non-neutral , politically charged instrument communication . linguistic elements serve represent views values particular social group . notion violence language suggests words may carry damaging meaning , oppression tool modern environment . arrigo ( 2019 ) states courtroom discourse often offensive participants process , representing phenomenon linguistic oppression , referring los angeles riots resulting situation . postmodern criminology aims investigating negative tendencies providing potential solutions . women appear one groups , experiencing system ’ oppression current settings . arrigo ( 2019 ) writes criminology education activities conducted white males representing middle class . accordingly , women pursue criminology professors ’ supervisors ’ views imposed . hegemony expressed particular linguistic patterns , reveal discriminatory nature thorough analysis .
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import pandas as pd 
ps = PorterStemmer()
tokens = word_tokenize(x)
print(tokens)
stemmed = []
for token in tokens:
     stemmed_word = ps.stem(token)
     stemmed.append(stemmed_word)
print(stemmed)
df = pd.DataFrame(data={"tokens":tokens, "stemmed": stemmed})
# Out:
# ['starting', 'from', 'the', '1990s', ',', 'postmodern', 'criminology', 'has', 'been', 'gaining', 'substantial', 'importance', '.', 'this', 'discipline', 'lays', 'particular', 'emphasis', 'on', 'such', 'aspects', 'as', 'gender', ',', 'class', ',', 'and', 'race', 'in', 'its', 'theories', 'of', 'the', 'origins', 'of', 'crime', '.', 'according', 'to', 'arrigo', '(', '2019', ')', ',', 'postmodern', 'criminology', 'recognizes', 'the', 'specific', 'value', 'of', 'language', 'as', 'a', 'non-neutral', ',', 'politically', 'charged', 'instrument', 'of', 'communication', '.', 'linguistic', 'elements', 'serve', 'to', 'represent', 'the', 'views', 'and', 'the', 'values', 'of', 'a', 'particular', 'social', 'group', '.', 'such', 'a', 'notion', 'as', 'the', 'violence', 'of', 'language', 'suggests', 'that', 'words', 'may', 'carry', 'damaging', 'meaning', ',', 'being', 'an', 'oppression', 'tool', 'in', 'the', 'modern', 'environment', '.', 'arrigo', '(', '2019', ')', 'states', 'that', 'the', 'courtroom', 'discourse', 'is', 'often', 'offensive', 'to', 'some', 'participants', 'of', 'the', 'process', ',', 'representing', 'the', 'phenomenon', 'of', 'linguistic', 'oppression', ',', 'referring', 'to', 'the', 'los', 'angeles', 'riots', 'resulting', 'from', 'such', 'a', 'situation', '.', 'postmodern', 'criminology', 'aims', 'at', 'investigating', 'such', 'negative', 'tendencies', 'and', 'providing', 'potential', 'solutions', '.', 'women', 'appear', 'to', 'be', 'one', 'of', 'the', 'groups', ',', 'which', 'have', 'been', 'experiencing', 'the', 'system', '’', 's', 'oppression', 'in', 'current', 'settings', '.', 'arrigo', '(', '2019', ')', 'writes', 'that', 'most', 'criminology', 'education', 'activities', 'are', 'conducted', 'by', 'white', 'males', 'representing', 'the', 'middle', 'class', '.', 'accordingly', ',', 'women', 'who', 'pursue', 'criminology', 'have', 'their', 'professors', '’', 'and', 'supervisors', '’', 'views', 'imposed', 'on', 'them', '.', 'this', 'hegemony', 'is', 'expressed', 'through', 'particular', 'linguistic', 'patterns', ',', 'which', 'reveal', 'their', 'discriminatory', 'nature', 'after', 'thorough', 'analysis', '.']
# ['start', 'from', 'the', '1990', ',', 'postmodern', 'criminolog', 'ha', 'been', 'gain', 'substanti', 'import', '.', 'thi', 'disciplin', 'lay', 'particular', 'emphasi', 'on', 'such', 'aspect', 'as', 'gender', ',', 'class', ',', 'and', 'race', 'in', 'it', 'theori', 'of', 'the', 'origin', 'of', 'crime', '.', 'accord', 'to', 'arrigo', '(', '2019', ')', ',', 'postmodern', 'criminolog', 'recogn', 'the', 'specif', 'valu', 'of', 'languag', 'as', 'a', 'non-neutr', ',', 'polit', 'charg', 'instrument', 'of', 'commun', '.', 'linguist', 'element', 'serv', 'to', 'repres', 'the', 'view', 'and', 'the', 'valu', 'of', 'a', 'particular', 'social', 'group', '.', 'such', 'a', 'notion', 'as', 'the', 'violenc', 'of', 'languag', 'suggest', 'that', 'word', 'may', 'carri', 'damag', 'mean', ',', 'be', 'an', 'oppress', 'tool', 'in', 'the', 'modern', 'environ', '.', 'arrigo', '(', '2019', ')', 'state', 'that', 'the', 'courtroom', 'discours', 'is', 'often', 'offens', 'to', 'some', 'particip', 'of', 'the', 'process', ',', 'repres', 'the', 'phenomenon', 'of', 'linguist', 'oppress', ',', 'refer', 'to', 'the', 'lo', 'angel', 'riot', 'result', 'from', 'such', 'a', 'situat', '.', 'postmodern', 'criminolog', 'aim', 'at', 'investig', 'such', 'neg', 'tendenc', 'and', 'provid', 'potenti', 'solut', '.', 'women', 'appear', 'to', 'be', 'one', 'of', 'the', 'group', ',', 'which', 'have', 'been', 'experienc', 'the', 'system', '’', 's', 'oppress', 'in', 'current', 'set', '.', 'arrigo', '(', '2019', ')', 'write', 'that', 'most', 'criminolog', 'educ', 'activ', 'are', 'conduct', 'by', 'white', 'male', 'repres', 'the', 'middl', 'class', '.', 'accordingli', ',', 'women', 'who', 'pursu', 'criminolog', 'have', 'their', 'professor', '’', 'and', 'supervisor', '’', 'view', 'impos', 'on', 'them', '.', 'thi', 'hegemoni', 'is', 'express', 'through', 'particular', 'linguist', 'pattern', ',', 'which', 'reveal', 'their', 'discriminatori', 'natur', 'after', 'thorough', 'analysi', '.']

# %%
import nltk
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
punctuations="?:!.,;"
sentence_words = nltk.word_tokenize(x)
for word in sentence_words:
    if word in punctuations:
        sentence_words.remove(word)

sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
    print ("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word)))
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Word                Lemma
# starting            starting
# from                from
# the                 the
# 1990s               1990s
# postmodern          postmodern
# criminology         criminology
# has                 ha
# been                been
# gaining             gaining
# substantial         substantial
# importance          importance
# this                this
# discipline          discipline
# lays                lay
# particular          particular
# emphasis            emphasis
# on                  on
# such                such
# aspects             aspect
# as                  a
# gender              gender
# class               class
# and                 and
# race                race
# in                  in
# its                 it
# theories            theory
# of                  of
# the                 the
# origins             origin
# of                  of
# crime               crime
# according           according
# to                  to
# arrigo              arrigo
# (                   (
# 2019                2019
# )                   )
# postmodern          postmodern
# criminology         criminology
# recognizes          recognizes
# the                 the
# specific            specific
# value               value
# of                  of
# language            language
# as                  a
# a                   a
# non-neutral         non-neutral
# politically         politically
# charged             charged
# instrument          instrument
# of                  of
# communication       communication
# linguistic          linguistic
# elements            element
# serve               serve
# to                  to
# represent           represent
# the                 the
# views               view
# and                 and
# the                 the
# values              value
# of                  of
# a                   a
# particular          particular
# social              social
# group               group
# such                such
# a                   a
# notion              notion
# as                  a
# the                 the
# violence            violence
# of                  of
# language            language
# suggests            suggests
# that                that
# words               word
# may                 may
# carry               carry
# damaging            damaging
# meaning             meaning
# being               being
# an                  an
# oppression          oppression
# tool                tool
# in                  in
# the                 the
# modern              modern
# environment         environment
# arrigo              arrigo
# (                   (
# 2019                2019
# )                   )
# states              state
# that                that
# the                 the
# courtroom           courtroom
# discourse           discourse
# is                  is
# often               often
# offensive           offensive
# to                  to
# some                some
# participants        participant
# of                  of
# the                 the
# process             process
# representing        representing
# the                 the
# phenomenon          phenomenon
# of                  of
# linguistic          linguistic
# oppression          oppression
# referring           referring
# to                  to
# the                 the
# los                 los
# angeles             angeles
# riots               riot
# resulting           resulting
# from                from
# such                such
# a                   a
# situation           situation
# postmodern          postmodern
# criminology         criminology
# aims                aim
# at                  at
# investigating       investigating
# such                such
# negative            negative
# tendencies          tendency
# and                 and
# providing           providing
# potential           potential
# solutions           solution
# women               woman
# appear              appear
# to                  to
# be                  be
# one                 one
# of                  of
# the                 the
# groups              group
# which               which
# have                have
# been                been
# experiencing        experiencing
# the                 the
# system              system
# ’                   ’
# s                   s
# oppression          oppression
# in                  in
# current             current
# settings            setting
# arrigo              arrigo
# (                   (
# 2019                2019
# )                   )
# writes              writes
# that                that
# most                most
# criminology         criminology
# education           education
# activities          activity
# are                 are
# conducted           conducted
# by                  by
# white               white
# males               male
# representing        representing
# the                 the
# middle              middle
# class               class
# accordingly         accordingly
# women               woman
# who                 who
# pursue              pursue
# criminology         criminology
# have                have
# their               their
# professors          professor
# ’                   ’
# and                 and
# supervisors         supervisor
# ’                   ’
# views               view
# imposed             imposed
# on                  on
# them                them
# this                this
# hegemony            hegemony
# is                  is
# expressed           expressed
# through             through
# particular          particular
# linguistic          linguistic
# patterns            pattern
# which               which
# reveal              reveal
# their               their
# discriminatory      discriminatory
# nature              nature
# after               after
# thorough            thorough
# analysis            analysis

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
stop_words = set(stopwords.words('english'))
tokenized = sent_tokenize(x)
for i in tokenized:
	wordsList = nltk.word_tokenize(i)
	wordsList = [w for w in wordsList if not w in stop_words]
	tagged = nltk.pos_tag(wordsList)
	print(tagged)
# Out:
# [('starting', 'VBG'), ('1990s', 'CD'), (',', ','), ('postmodern', 'JJ'), ('criminology', 'NN'), ('gaining', 'VBG'), ('substantial', 'JJ'), ('importance', 'NN'), ('.', '.')]
# [('discipline', 'NN'), ('lays', 'VBZ'), ('particular', 'JJ'), ('emphasis', 'NN'), ('aspects', 'NNS'), ('gender', 'VBP'), (',', ','), ('class', 'NN'), (',', ','), ('race', 'NN'), ('theories', 'NNS'), ('origins', 'VBZ'), ('crime', 'NN'), ('.', '.')]
# [('according', 'VBG'), ('arrigo', 'NN'), ('(', '('), ('2019', 'CD'), (')', ')'), (',', ','), ('postmodern', 'JJ'), ('criminology', 'NN'), ('recognizes', 'VBZ'), ('specific', 'JJ'), ('value', 'NN'), ('language', 'NN'), ('non-neutral', 'JJ'), (',', ','), ('politically', 'RB'), ('charged', 'VBN'), ('instrument', 'NN'), ('communication', 'NN'), ('.', '.')]
# [('linguistic', 'JJ'), ('elements', 'NNS'), ('serve', 'VBP'), ('represent', 'JJ'), ('views', 'NNS'), ('values', 'NNS'), ('particular', 'JJ'), ('social', 'JJ'), ('group', 'NN'), ('.', '.')]
# [('notion', 'NN'), ('violence', 'NN'), ('language', 'NN'), ('suggests', 'VBZ'), ('words', 'NNS'), ('may', 'MD'), ('carry', 'VB'), ('damaging', 'VBG'), ('meaning', 'NN'), (',', ','), ('oppression', 'NN'), ('tool', 'NN'), ('modern', 'JJ'), ('environment', 'NN'), ('.', '.')]
# [('arrigo', 'NN'), ('(', '('), ('2019', 'CD'), (')', ')'), ('states', 'VBZ'), ('courtroom', 'JJ'), ('discourse', 'NN'), ('often', 'RB'), ('offensive', 'JJ'), ('participants', 'NNS'), ('process', 'NN'), (',', ','), ('representing', 'VBG'), ('phenomenon', 'NN'), ('linguistic', 'JJ'), ('oppression', 'NN'), (',', ','), ('referring', 'VBG'), ('los', 'JJ'), ('angeles', 'NNS'), ('riots', 'NNS'), ('resulting', 'VBG'), ('situation', 'NN'), ('.', '.')]
# [('postmodern', 'JJ'), ('criminology', 'NN'), ('aims', 'NNS'), ('investigating', 'VBG'), ('negative', 'JJ'), ('tendencies', 'NNS'), ('providing', 'VBG'), ('potential', 'JJ'), ('solutions', 'NNS'), ('.', '.')]
# [('women', 'NNS'), ('appear', 'VBP'), ('one', 'CD'), ('groups', 'NNS'), (',', ','), ('experiencing', 'VBG'), ('system', 'NN'), ('’', 'JJ'), ('oppression', 'NN'), ('current', 'JJ'), ('settings', 'NNS'), ('.', '.')]
# [('arrigo', 'NN'), ('(', '('), ('2019', 'CD'), (')', ')'), ('writes', 'VBZ'), ('criminology', 'JJ'), ('education', 'NN'), ('activities', 'NNS'), ('conducted', 'VBD'), ('white', 'JJ'), ('males', 'NNS'), ('representing', 'VBG'), ('middle', 'JJ'), ('class', 'NN'), ('.', '.')]
# [('accordingly', 'RB'), (',', ','), ('women', 'NNS'), ('pursue', 'VBP'), ('criminology', 'NN'), ('professors', 'NNS'), ('’', 'VBP'), ('supervisors', 'NNS'), ('’', 'VBP'), ('views', 'NNS'), ('imposed', 'VBN'), ('.', '.')]
# [('hegemony', 'NN'), ('expressed', 'VBD'), ('particular', 'JJ'), ('linguistic', 'JJ'), ('patterns', 'NNS'), (',', ','), ('reveal', 'JJ'), ('discriminatory', 'JJ'), ('nature', 'NN'), ('thorough', 'IN'), ('analysis', 'NN'), ('.', '.')]
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/josiahjames/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
